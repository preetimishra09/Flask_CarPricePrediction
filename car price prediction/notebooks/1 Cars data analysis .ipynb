# %%
import pandas as pd
df=pd.read_csv("../data/raw/car data.csv")

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# ...

# %%
df.Fuel_Type.value_counts()
# Out:
# Petrol    139
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
df['new_Selling_Price']=df['Selling_Price']*100000
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  new_Selling_Price
# 0      Dealer       Manual      0           335000.0
# 1      Dealer       Manual      0           475000.0
# 2      Dealer       Manual      0           725000.0
# 3      Dealer       Manual      0           285000.0
# 4      Dealer       Manual      0           460000.0

# %%
df['new_Present_Price']=df['Present_Price']*100000
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  new_Selling_Price  new_Present_Price
# 0      Dealer       Manual      0           335000.0           559000.0
# 1      Dealer       Manual      0           475000.0           954000.0
# 2      Dealer       Manual      0           725000.0           985000.0
# 3      Dealer       Manual      0           285000.0           415000.0
# 4      Dealer       Manual      0           460000.0           687000.0

# %%
from datetime import date
  
# creating the date object of today's date
todays_date = date.today()
print(todays_date)

df["Car_Age"]=todays_date.year-df['Year']
df.head()
# Out:
# 2022-11-22
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  new_Selling_Price  new_Present_Price  \
# 0      Dealer       Manual      0           335000.0           559000.0
# 1      Dealer       Manual      0           475000.0           954000.0
# 2      Dealer       Manual      0           725000.0           985000.0
# 3      Dealer       Manual      0           285000.0           415000.0
# 4      Dealer       Manual      0           460000.0           687000.0
#
#    Car_Age
# 0        8
# 1        9
# 2        5
# 3       11
# 4        8

# %%
df.drop(["Year","Selling_Price","Present_Price"],axis=1,inplace=True)
df.head()
# Out:
#   Car_Name  Kms_Driven Fuel_Type Seller_Type Transmission  Owner  \
# 0     ritz       27000    Petrol      Dealer       Manual      0
# 1      sx4       43000    Diesel      Dealer       Manual      0
# 2     ciaz        6900    Petrol      Dealer       Manual      0
# 3  wagon r        5200    Petrol      Dealer       Manual      0
# 4    swift       42450    Diesel      Dealer       Manual      0
#
#    new_Selling_Price  new_Present_Price  Car_Age
# 0           335000.0           559000.0        8
# 1           475000.0           954000.0        9
# 2           725000.0           985000.0        5
# 3           285000.0           415000.0       11
# 4           460000.0           687000.0        8

# %%
cor_mat=df.corr()
cor_mat
# Out:
#                    Kms_Driven     Owner  new_Selling_Price  new_Present_Price  \
# Kms_Driven           1.000000  0.197756          -0.101332           0.253505
# Owner                0.197756  1.000000          -0.083620           0.047002
# new_Selling_Price   -0.101332 -0.083620           1.000000           0.826635
# new_Present_Price    0.253505  0.047002           0.826635           1.000000
# Car_Age              0.705477  0.152243          -0.346141           0.060279
#
#                     Car_Age
# Kms_Driven         0.705477
# Owner              0.152243
# new_Selling_Price -0.346141
# new_Present_Price  0.060279
# Car_Age            1.000000

# %%
import seaborn as sns
sns.heatmap(cor_mat,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.drop(['Owner'],axis=1,inplace = True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16404/531386436.py in <module>
# ----> 1 df.drop(['Owner'],axis=1,inplace = True)
#       2 df.head()
#
# c:\Users\nilay\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\nilay\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
sns.countplot(df['Seller_Type'])
# Out:
# c:\Users\nilay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Seller_Type', ylabel='count'>

# %%
sns.scatterplot(df['Seller_Type'],df['new_Selling_Price'])
# Out:
# c:\Users\nilay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Seller_Type', ylabel='new_Selling_Price'>

# %%
df.drop(['Seller_Type'],axis=1,inplace = True)
df.head()
# Out:
#   Car_Name  Kms_Driven Fuel_Type Transmission  new_Selling_Price  \
# 0     ritz       27000    Petrol       Manual           335000.0
# 1      sx4       43000    Diesel       Manual           475000.0
# 2     ciaz        6900    Petrol       Manual           725000.0
# 3  wagon r        5200    Petrol       Manual           285000.0
# 4    swift       42450    Diesel       Manual           460000.0
#
#    new_Present_Price  Car_Age
# 0           559000.0        8
# 1           954000.0        9
# 2           985000.0        5
# 3           415000.0       11
# 4           687000.0        8

# %%
df['Car_Name'].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Yamaha Fazer ', 'i20', 'grand i10',
#        'i10', 'eon', 'xcent', 'elantra', 'creta', 'verna', 'city', 'brio',
#        'amaze', 'jazz'], dtype=object)

# %%
for i in df['Car_Name'].value_counts().index:
    print(i)
# Out:
# city
# corolla altis
# verna
# fortuner
# brio
# ciaz
# innova
# i20
# grand i10
# jazz
# amaze
# sx4
# ertiga
# eon
# alto k10
# i10
# swift
# etios liva
# ritz
# dzire
# wagon r
# etios cross
# creta
# xcent
# etios g
# elantra
# Yamaha Fazer
# baleno
# 800
# omni
# land cruiser
# camry
# etios gd
# alto 800
# s cross
# vitara brezza
# corolla
# ignis

# %%
df[df['Car_Name']=='Yamaha Fazer ']
# Out:
#           Car_Name  Kms_Driven Fuel_Type Transmission  new_Selling_Price  \
# 100  Yamaha Fazer         8000    Petrol       Manual            50000.0
#
#      new_Present_Price  Car_Age
# 100            88000.0        8

# %%
df[df['Car_Name']=='Yamaha Fazer '].index
# Out:
# Int64Index([100], dtype='int64')

# %%
df.drop(100,axis=0,inplace=True)

# %%
df[df['Car_Name']=='Yamaha Fazer ']
# Out:
# Empty DataFrame
# Columns: [Car_Name, Kms_Driven, Fuel_Type, Transmission, new_Selling_Price, new_Present_Price, Car_Age]
# Index: []

# %%
df.drop(['Car_Name'],axis=1,inplace = True)
df.head()
# Out:
#    Kms_Driven Fuel_Type Transmission  new_Selling_Price  new_Present_Price  \
# 0       27000    Petrol       Manual           335000.0           559000.0
# 1       43000    Diesel       Manual           475000.0           954000.0
# 2        6900    Petrol       Manual           725000.0           985000.0
# 3        5200    Petrol       Manual           285000.0           415000.0
# 4       42450    Diesel       Manual           460000.0           687000.0
#
#    Car_Age
# 0        8
# 1        9
# 2        5
# 3       11
# 4        8

# %%
pd.get_dummies(df,drop_first=True)
# Out:
#      Kms_Driven  new_Selling_Price  new_Present_Price  Car_Age  \
# 0         27000           335000.0           559000.0        8
# 1         43000           475000.0           954000.0        9
# 2          6900           725000.0           985000.0        5
# 3          5200           285000.0           415000.0       11
# 4         42450           460000.0           687000.0        8
# ..          ...                ...                ...      ...
# 196       33988           950000.0          1160000.0        6
# 197       60000           400000.0           590000.0        7
# 198       87934           335000.0          1100000.0       13
# 199        9000          1150000.0          1250000.0        5
# 200        5464           530000.0           590000.0        6
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Transmission_Manual
# 0                   0                 1                    1
# 1                   1                 0                    1
# ...

# %%
df=pd.get_dummies(df,drop_first=True)
df.head()
# Out:
#    Kms_Driven  new_Selling_Price  new_Present_Price  Car_Age  \
# 0       27000           335000.0           559000.0        8
# 1       43000           475000.0           954000.0        9
# 2        6900           725000.0           985000.0        5
# 3        5200           285000.0           415000.0       11
# 4       42450           460000.0           687000.0        8
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Transmission_Manual
# 0                 0                 1                    1
# 1                 1                 0                    1
# 2                 0                 1                    1
# 3                 0                 1                    1
# 4                 1                 0                    1

# %%
df.to_csv("../data/processed data/cleaned_data_v1.csv",index=False)
